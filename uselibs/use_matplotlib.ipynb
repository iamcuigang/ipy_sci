# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)
z = np.cos(x**2)

plt.figure(figsize=(8,4))
plt.plot(x, y, label='$sin(x)$', color='c', linewidth=1)
plt.plot(x, z, 'y--', label='$cos(x^2)$')

plt.xlabel('Time(s)')
plt.ylabel('Volt')
plt.title('pyplot example')
plt.ylim(-1.2, 1.2)
plt.legend()
plt.show()
